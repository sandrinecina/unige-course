# %%
# %pip install --upgrade langchain langchain-experimental langchain-openai python-dotenv pyvis
# Out:
# Collecting langchain
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-experimental
#   Using cached langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-openai
#   Using cached langchain_openai-0.3.32-py3-none-any.whl.metadata (2.4 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting pyvis
#   Using cached pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Using cached langchain_core-0.3.75-py3-none-any.whl.metadata (5.7 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Downloading langchain_text_splitters-0.3.10-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.21-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.43-cp313-cp313-macosx_10_13_x86_64.whl.metadata (9.6 kB)
# Collecting requests<3,>=2 (from langchain)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.2-cp313-cp313-macosx_10_13_x86_64.whl.metadata (2.1 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting typing-extensions>=4.7 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=23.2 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pip>=25.2 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from langchain-text-splitters<1.0.0,>=0.3.9->langchain) (25.2)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.33.2-cp313-cp313-macosx_10_12_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Downloading charset_normalizer-3.4.3-cp313-cp313-macosx_10_13_universal2.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.2.4-cp313-cp313-macosx_11_0_universal2.whl.metadata (4.1 kB)
# Collecting langchain-community<0.4.0,>=0.3.0 (from langchain-experimental)
#   Downloading langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Downloading aiohttp-3.12.15-cp313-cp313-macosx_10_13_x86_64.whl.metadata (7.7 kB)
# Collecting dataclasses-json<0.7,>=0.6.7 (from langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting numpy>=2.1.0 (from langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Downloading numpy-2.3.2-cp313-cp313-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Downloading frozenlist-1.7.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Downloading multidict-6.6.4-cp313-cp313-macosx_10_13_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Downloading propcache-0.3.2-cp313-cp313-macosx_10_13_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Downloading yarl-1.20.1-cp313-cp313-macosx_10_13_x86_64.whl.metadata (73 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting openai<2.0.0,>=1.99.9 (from langchain-openai)
#   Using cached openai-1.102.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.11.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (6.7 kB)
# Collecting anyio<5,>=3.5.0 (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Downloading jiter-0.10.0-cp313-cp313-macosx_10_12_x86_64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.99.9->langchain-openai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.99.9->langchain-openai)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Downloading regex-2025.8.29-cp313-cp313-macosx_10_13_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: ipython>=5.3.0 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from pyvis) (9.5.0)
# Collecting jinja2>=2.9.6 (from pyvis)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Using cached jsonpickle-4.1.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting networkx>=1.11 (from pyvis)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: decorator in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (2.19.2)
# Requirement already satisfied: stack_data in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.5)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9.6->pyvis)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (4.0 kB)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.3-cp313-cp313-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Downloading zstandard-0.24.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from stack_data->ipython>=5.3.0->pyvis) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from stack_data->ipython>=5.3.0->pyvis) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/path/to/venv/lib/python3.13/site-packages (from stack_data->ipython>=5.3.0->pyvis) (0.2.3)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.75-py3-none-any.whl (443 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.10-py3-none-any.whl (34 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-macosx_10_12_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.7 MB/s  0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp313-cp313-macosx_10_13_universal2.whl (205 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading sqlalchemy-2.0.43-cp313-cp313-macosx_10_13_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.4 MB/s  0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
# Downloading langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 27.8 MB/s  0:00:00
# Downloading aiohttp-3.12.15-cp313-cp313-macosx_10_13_x86_64.whl (474 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.6.4-cp313-cp313-macosx_10_13_x86_64.whl (45 kB)
# Using cached pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.20.1-cp313-cp313-macosx_10_13_x86_64.whl (90 kB)
# Using cached langchain_openai-0.3.32-py3-none-any.whl (74 kB)
# Using cached openai-1.102.0-py3-none-any.whl (812 kB)
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.10.0-cp313-cp313-macosx_10_12_x86_64.whl (311 kB)
# Downloading tiktoken-0.11.0-cp313-cp313-macosx_10_13_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.5 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached pyvis-0.3.2-py3-none-any.whl (756 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading frozenlist-1.7.0-cp313-cp313-macosx_10_13_x86_64.whl (47 kB)
# Downloading greenlet-3.2.4-cp313-cp313-macosx_11_0_universal2.whl (272 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached jsonpickle-4.1.1-py3-none-any.whl (47 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading langsmith-0.4.21-py3-none-any.whl (378 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-macosx_10_13_universal2.whl (14 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.3 MB/s  0:00:00
# Downloading numpy-2.3.2-cp313-cp313-macosx_14_0_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 32.4 MB/s  0:00:00
# Downloading orjson-3.11.3-cp313-cp313-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (238 kB)
# Downloading propcache-0.3.2-cp313-cp313-macosx_10_13_x86_64.whl (42 kB)
# Downloading PyYAML-6.0.2-cp313-cp313-macosx_10_13_x86_64.whl (181 kB)
# Downloading regex-2025.8.29-cp313-cp313-macosx_10_13_x86_64.whl (290 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading zstandard-0.24.0-cp313-cp313-macosx_10_13_x86_64.whl (795 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.7/795.7 kB 11.0 MB/s  0:00:00
# Installing collected packages: zstandard, urllib3, typing-extensions, tqdm, tenacity, sniffio, regex, PyYAML, python-dotenv, propcache, orjson, numpy, networkx, mypy-extensions, multidict, marshmallow, MarkupSafe, jsonpointer, jsonpickle, jiter, idna, httpx-sse, h11, greenlet, frozenlist, distro, charset_normalizer, certifi, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspection, typing-inspect, SQLAlchemy, requests, pydantic-core, jsonpatch, jinja2, httpcore, anyio, aiosignal, tiktoken, requests-toolbelt, pyvis, pydantic, httpx, dataclasses-json, aiohttp, pydantic-settings, openai, langsmith, langchain-core, langchain-text-splitters, langchain-openai, langchain, langchain-community, langchain-experimental
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58/58 [langchain-experimental]rimental]unity]
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 SQLAlchemy-2.0.43 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 annotated-types-0.7.0 anyio-4.10.0 attrs-25.3.0 certifi-2025.8.3 charset_normalizer-3.4.3 dataclasses-json-0.6.7 distro-1.9.0 frozenlist-1.7.0 greenlet-3.2.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 httpx-sse-0.4.1 idna-3.10 jinja2-3.1.6 jiter-0.10.0 jsonpatch-1.33 jsonpickle-4.1.1 jsonpointer-3.0.0 langchain-0.3.27 langchain-community-0.3.29 langchain-core-0.3.75 langchain-experimental-0.3.4 langchain-openai-0.3.32 langchain-text-splitters-0.3.10 langsmith-0.4.21 marshmallow-3.26.1 multidict-6.6.4 mypy-extensions-1.1.0 networkx-3.5 numpy-2.3.2 openai-1.102.0 orjson-3.11.3 propcache-0.3.2 pydantic-2.11.7 pydantic-core-2.33.2 pydantic-settings-2.10.1 python-dotenv-1.1.1 pyvis-0.3.2 regex-2025.8.29 requests-2.32.5 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 tiktoken-0.11.0 tqdm-4.67.1 typing-extensions-4.15.0 typing-inspect-0.9.0 typing-inspection-0.4.1 urllib3-2.5.0 yarl-1.20.1 zstandard-0.24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LLAMA_API_KEY"] = os.getenv("LLAMA_API_KEY")

# %% [markdown]
# ### LLM Graph Transformer from Langchain ###

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o", temperature=0)

graph_transformer = LLMGraphTransformer(llm=llm)

# %%
text = """
Kayleigh Rose Amstutz (born February 19, 1998), known professionally as Chappell Roan (/ˌtʃæpəl ˈroʊn/ ⓘ CHAP-əl ROHN), is an American singer and songwriter. She is known for her camp and drag queen–influenced aesthetic.[1] Her debut EP, School Nights (2017), was released by Atlantic Records. After years without success, she was dropped from the label in 2020. Her debut studio album, The Rise and Fall of a Midwest Princess (2023), was released through Island Records and received critical acclaim. The album garnered a cult following and became a sleeper hit.

Roan rose to prominence in 2024 with the single "Good Luck, Babe!", which reached number four on the US Billboard Hot 100 and became a global top-five single. It was a catalyst for the success of her debut album, which eventually topped the charts in the UK, Ireland, and New Zealand and reached number two on the US Billboard 200. Several album tracks subsequently entered various charts, including "Hot to Go!" and "Pink Pony Club", which both reached the top five in the UK. At the 67th Grammy Awards, Roan became one of only 15 artists to be nominated for all the "Big Four" awards in one night, winning Best New Artist.

Her stage name, Chappell Roan, is a combination of the name of her grandfather, Dennis K. Chappell, who died of brain cancer, and a word taken from his favorite song, "The Strawberry Roan" by Curley Fletcher.

Early life
Kayleigh Rose Amstutz was born in Willard, Missouri, on February 19, 1998,[2][3][4] the oldest of four children.[5][6][7] Her mother, Kara (née Chappell),[8][9] is a veterinarian; her father, Dwight Amstutz, is now a retired Naval Reservist who also managed the family's veterinary practice in Springfield, Missouri, and earlier trained as a registered nurse, working in neurological and burn intensive care units.[10][11][12] Her uncle is Missouri State Representative Darin Chappell.[13]

"""

# %%
documents = [Document(page_content=text)]
graph_documents = await graph_transformer.aconvert_to_graph_documents(documents)

# %%
print(f"Nodes: {graph_documents[0].nodes}")
print(f"Relationships: {graph_documents[0].relationships}")
# Out:
# Nodes: [Node(id='Kayleigh Rose Amstutz', type='Person', properties={}), Node(id='Chappell Roan', type='Person', properties={}), Node(id='American', type='Nationality', properties={}), Node(id='Singer', type='Occupation', properties={}), Node(id='Songwriter', type='Occupation', properties={}), Node(id='School Nights', type='Album', properties={}), Node(id='Atlantic Records', type='Organization', properties={}), Node(id='The Rise And Fall Of A Midwest Princess', type='Album', properties={}), Node(id='Island Records', type='Organization', properties={}), Node(id='Good Luck, Babe!', type='Song', properties={}), Node(id='Us Billboard Hot 100', type='Chart', properties={}), Node(id='Uk', type='Location', properties={}), Node(id='Ireland', type='Location', properties={}), Node(id='New Zealand', type='Location', properties={}), Node(id='Us Billboard 200', type='Chart', properties={}), Node(id='Hot To Go!', type='Song', properties={}), Node(id='Pink Pony Club', type='Song', properties={}), Node(id='67Th Grammy Awards', type='Event', properties={}), Node(id='Best New Artist', type='Award', properties={}), Node(id='Dennis K. Chappell', type='Person', properties={}), Node(id='The Strawberry Roan', type='Song', properties={}), Node(id='Curley Fletcher', type='Person', properties={}), Node(id='Willard, Missouri', type='Location', properties={}), Node(id='February 19, 1998', type='Date', properties={}), Node(id='Kara Chappell', type='Person', properties={}), Node(id='Veterinarian', type='Occupation', properties={}), Node(id='Dwight Amstutz', type='Person', properties={}), Node(id='Naval Reservist', type='Occupation', properties={}), Node(id='Darin Chappell', type='Person', properties={}), Node(id='Missouri State Representative', type='Occupation', properties={}), Node(id='Christian', type='Religion', properties={}), Node(id='Piano', type='Instrument', properties={}), Node(id="America'S Got Talent", type='Event', properties={}), Node(id='Youtube', type='Platform', properties={}), Node(id='Willard High School', type='Organization', properties={}), Node(id='Dan Nigro', type='Person', properties={}), Node(id='Pink Pony Club', type='Song', properties={}), Node(id='The Abbey', type='Location', properties={}), Node(id='Los Angeles', type='Location', properties={}), Node(id='Sony', type='Organization', properties={}), Node(id='Naked In Manhattan', type='Song', properties={}), Node(id='Olivia Rodrigo', type='Person', properties={}), Node(id='Sour Tour', type='Event', properties={}), Node(id='Fletcher', type='Person', properties={}), Node(id='Girl Of My Dreams Tour', type='Event', properties={}), Node(id='Femininomenon', type='Song', properties={}), Node(id='Casual', type='Song', properties={}), Node(id='Naked In North America Tour', type='Event', properties={}), Node(id='Amusement Records', type='Organization', properties={}), Node(id='Midwest Princess Tour', type='Event', properties={}), Node(id='For The Gworls', type='Organization', properties={}), Node(id="Olivia Rodrigo'S Guts World Tour", type='Event', properties={}), Node(id='The Late Show With Stephen Colbert', type='Event', properties={}), Node(id='Tiny Desk Concert', type='Event', properties={}), Node(id='Coachella', type='Event', properties={}), Node(id='Governors Ball Music Festival', type='Event', properties={}), Node(id='The Subway', type='Song', properties={}), Node(id='Lollapalooza', type='Event', properties={}), Node(id='2024 Mtv Video Music Awards', type='Event', properties={}), Node(id='Best New Artist', type='Award', properties={}), Node(id='Billboard Artist 100', type='Chart', properties={}), Node(id='Saturday Night Live', type='Event', properties={}), Node(id='John Mulaney', type='Person', properties={}), Node(id='The Giver', type='Song', properties={}), Node(id='A Nonsense Christmas', type='Event', properties={}), Node(id='Sabrina Carpenter', type='Person', properties={}), Node(id='Sound Of 2025', type='Award', properties={}), Node(id='Bbc', type='Organization', properties={}),  ...
# Relationships: [Relationship(source=Node(id='Kayleigh Rose Amstutz', type='Person', properties={}), target=Node(id='Chappell Roan', type='Person', properties={}), type='STAGE_NAME', properties={}), Relationship(source=Node(id='Chappell Roan', type='Person', properties={}), target=Node(id='American', type='Nationality', properties={}), type='HAS_NATIONALITY', properties={}), Relationship(source=Node(id='Chappell Roan', type='Person', properties={}), target=Node(id='Singer', type='Occupation', properties={}), type='HAS_OCCUPATION', properties={}), Relationship(source=Node(id='Chappell Roan', type='Person', properties={}), target=Node(id='Songwriter', type='Occupation', properties={}), type='HAS_OCCUPATION', properties={}), Relationship(source=Node(id='School Nights', type='Album', properties={}), target=Node(id='Atlantic Records', type='Organization', properties={}), type='RELEASED_BY', properties={}), Relationship(source=Node(id='The Rise And Fall Of A Midwest Princess', type='Album', properties={}), target=Node(id='Island Records', type='Organization', properties={}), type='RELEASED_BY', properties={}), Relationship(source=Node(id='Good Luck, Babe!', type='Song', properties={}), target=Node(id='Us Billboard Hot 100', type='Chart', properties={}), type='REACHED_NUMBER_FOUR_ON', properties={}), Relationship(source=Node(id='The Rise And Fall Of A Midwest Princess', type='Album', properties={}), target=Node(id='Uk', type='Location', properties={}), type='TOPPED_CHARTS_IN', properties={}), Relationship(source=Node(id='The Rise And Fall Of A Midwest Princess', type='Album', properties={}), target=Node(id='Ireland', type='Location', properties={}), type='TOPPED_CHARTS_IN', properties={}), Relationship(source=Node(id='The Rise And Fall Of A Midwest Princess', type='Album', properties={}), target=Node(id='New Zealand', type='Location', properties={}), type='TOPPED_CHARTS_IN', properties={}), Relationship(source=Node(id='The Rise And Fall Of A Midwest Princess', type='Album', properties={}), target=Node(id='Us Billboard 200', type='Chart', properties={}), type='REACHED_NUMBER_TWO_ON', properties={}), Relationship(source=Node(id='Hot To Go!', type='Song', properties={}), target=Node(id='Uk', type='Location', properties={}), type='REACHED_TOP_FIVE_IN', properties={}), Relationship(source=Node(id='Pink Pony Club', type='Song', properties={}), target=Node(id='Uk', type='Location', properties={}), type='REACHED_TOP_FIVE_IN', properties={}), Relationship(source=Node(id='Chappell Roan', type='Person', properties={}), target=Node(id='67Th Grammy Awards', type='Event', properties={}), type='NOMINATED_AT', properties={}), Relationship(source=Node(id='Chappell Roan', type='Person', properties={}), target=Node(id='Best New Artist', type='Award', properties={}), type='WON', properties={}), Relationship(source=Node(id='Chappell Roan', type='Person', properties={}), target=Node(id='Dennis K. Chappell', type='Person', properties={}), type='GRANDFATHER', properties={}), Relationship(source=Node(id='Dennis K. Chappell', type='Person', properties={}), target=Node(id='The Strawberry Roan', type='Song', properties={}), type='FAVORITE_SONG', properties={}), Relationship(source=Node(id='The Strawberry Roan', type='Song', properties={}), target=Node(id='Curley Fletcher', type='Person', properties={}), type='WRITTEN_BY', properties={}), Relationship(source=Node(id='Kayleigh Rose Amstutz', type='Person', properties={}), target=Node(id='Willard, Missouri', type='Location', properties={}), type='BORN_IN', properties={}), Relationship(source=Node(id='Kayleigh Rose Amstutz', type='Person', properties={}), target=Node(id='February 19, 1998', type='Date', properties={}), type='BIRTH_DATE', properties={}), Relationship(source=Node(id='Kayleigh Rose Amstutz', type='Person', properties={}), target=Node(id='Kara Chappell', type='Person', properties={}), type='MOTHER', properties={}), Relationship(source=Node(id='Kara Chappell', type='Person', properties={}), target=Node(i ...

# %% [markdown]
# ### Visualize Graph ###

# %%
from pyvis.network import Network

def visualize_graph(graph_documents):

    # Create network
    net = Network(height="1200px", width="100%", directed=True,
                      notebook=False, bgcolor="#222222", font_color="white")
    
    nodes = graph_documents[0].nodes
    relationships = graph_documents[0].relationships

    # Build lookup for valid nodes
    node_dict = {node.id: node for node in nodes}
    
    # Filter out invalid edges and collect valid node IDs
    valid_edges = []
    valid_node_ids = set()
    for rel in relationships:
        if rel.source.id in node_dict and rel.target.id in node_dict:
            valid_edges.append(rel)
            valid_node_ids.update([rel.source.id, rel.target.id])


    # Track which nodes are part of any relationship
    connected_node_ids = set()
    for rel in relationships:
        connected_node_ids.add(rel.source.id)
        connected_node_ids.add(rel.target.id)

    # Add valid nodes
    for node_id in valid_node_ids:
        node = node_dict[node_id]
        try:
            net.add_node(node.id, label=node.id, title=node.type, group=node.type)
        except:
            continue  # skip if error

    # Add valid edges
    for rel in valid_edges:
        try:
            net.add_edge(rel.source.id, rel.target.id, label=rel.type.lower())
        except:
            continue  # skip if error

    # Configure physics
    net.set_options("""
            {
                "physics": {
                    "forceAtlas2Based": {
                        "gravitationalConstant": -100,
                        "centralGravity": 0.01,
                        "springLength": 200,
                        "springConstant": 0.08
                    },
                    "minVelocity": 0.75,
                    "solver": "forceAtlas2Based"
                }
            }
            """)
        
    output_file = "knowledge_graph.html"
    net.save_graph(output_file)
    print(f"Graph saved to {os.path.abspath(output_file)}")

    # Try to open in browser
    try:
        import webbrowser
        webbrowser.open(f"file://{os.path.abspath(output_file)}")
    except:
        print("Could not open browser automatically")
        
# Run the function
visualize_graph(graph_documents)
# Out:
# Graph saved to /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/backend/knowledge_graph.html

# %% [markdown]
# ### Extract specific types of nodes ###

# %%
allowed_nodes = ["Organization"]
graph_transformer_nodes_defined = LLMGraphTransformer(llm=llm, allowed_nodes=allowed_nodes)
graph_documents_nodes_defined = await graph_transformer_nodes_defined.aconvert_to_graph_documents(documents)

# %%
print(f"Nodes:{graph_documents_nodes_defined[0].nodes}")
print(f"Relationships:{graph_documents_nodes_defined[0].relationships}")
# Out:
# Nodes:[Node(id='Société Suisse De La Sclérose En Plaques', type='Organization', properties={})]
# Relationships:[]

# %%
visualize_graph(graph_documents_nodes_defined)
# Out:
# Graph saved to /Users/sandrinecina/Documents/Dev/raisesquad-fullstack/backend/knowledge_graph.html
